# %% [markdown]
# <a href="https://colab.research.google.com/github/gyeoldere/LearningMachine/blob/master/DriveMounting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ###  드라이브를 마운트합니다.
# #### 실행 시 나오는 URL에 들어가 authorization code를 입력합니다.
# #### 성공 시 좌측 탭의 파일에 드라이브가 마운트 되어 있는 것을 확인할 수 있습니다.

# %%
import pandas as pd

test = pd.read_csv('/content/drive/My Drive/LearningMachine/데이터/20200413152223/새 폴더 (3)/차량통행속도 (1).csv', encoding='utf-8')
test.head()
# Out:
#    YYYYMMDD(년월일) WDAY(요일)  ... TIME_22_SPD(22시-23시_평균속도)  TIME_23_SPD(23시-24시_평균속도)
# 0       20151201        화  ...                     20.56                      26.82
# 1       20151202        수  ...                     23.90                      25.91
# 2       20151203        목  ...                     22.82                      23.19
# 3       20151204        금  ...                     22.47                      24.33
# 4       20151205        토  ...                     30.00                      30.00
#
# [5 rows x 32 columns]

# %% [markdown]
# ### 좌측의 파일 탭에서 특정 폴더나 파일을 우클릭하면 경로를 복사할 수 있습니다.
# ### 경로를 복사하면 자연스럽게 드라이브의 파일을 불러올 수 있습니다.
